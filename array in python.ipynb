# %%
import array as arr
a=arr.array("i",[1,3,7,4]) #creating an array and "i" is taken as an interger
for i in range(0,3):   
 print(a[i],end="  ")
print() #this print fun() is used to start or continue form next line
a.insert(0,5) #inserting into an array
for i in (a):
 print(i,end=" ")   # time complexcity O(n) – for inserting elements at the beginning of the array
print()
print("accessing the element at:",a[0])   #accessing the element with time complexcity O(1)
print()
#Elements can be removed from the Python array by using built-in remove() function but an Error arises if element doesn’t exist in the set. Remove() method only removes one element at a time, to remove range of elements, iterator is used. pop() function
for i in range(0,5):
    print(a[i], end=" ")

print("\r")
a.remove(1) #Time Complexity: O(1)/O(n) ( O(1) – for removing elements at the end of the array, O(n) – for removing elements at the beginning
for i in (a):
    print(i,end=" ")
print()
##slicing of an array
slice=a[:2]  #to print the array from beginning to the range use[:index value]
print(slice)
slice=a[:-1] #to print the element form the end use[:-index]
print(slice)
slice=a[1:3]#to print the element within a range use [starting index:ending index]
print(slice)
slice=a[:3]# to print elements from specific Index till the end use [Index:] 
print(slice)
slice=a[:]#it print whole arr or list with slicing
print(slice)
slice=a[::-1]# to print whole arr in reverse order
print(slice)

#searching element in array
for i in range(0,3):                           # O(n)
 print("\r") # use to leave space
print(a.index(5)) #syntax a.index(value in array) , it will return the index for the given value
#note: print function will come out of the for loop ,if it is within the for loop the it will print the output as many time as the for loop runs

#updating elements in array          #  O(n)
for i in range(0,4):    #In order to update an element in the array we simply reassign a new value to the desired index we want to update. 
    print(a[i],end=" ")                       
a[2]=9
print()
print("the update array is ")
for i in range(0,4):
  print(a[i],end=" ")
print()

#counting array                      #O(n)
count=a.count(3)               # it will print the count of the occurence of the variable in an array 
print("the occurence of the element:",count)

#extending  an array                  #O(
for i in range(0,4):
   print(a[i],end=" ")
print()
a.extend([6,7,8,9])
for i in (a):
  print(i,end=" ")


#NOTE:the syntax of the array can be applied on the list as well
# Out:
# 1  3  7
# 5 1 3 7 4
# accessing the element at: 5
#
# 5 1 3 7 4
# 5 3 7 4
# array('i', [5, 3])
# array('i', [5, 3, 7])
# array('i', [3, 7])
# array('i', [5, 3, 7])
# array('i', [5, 3, 7, 4])
# array('i', [4, 7, 3, 5])
#
#
#
# 0
# 5 3 7 4
# the update array is
# 5 3 9 4
# the occurence of the element: 1
# 5 3 9 4
# 5 3 9 4 6 7 8 9
